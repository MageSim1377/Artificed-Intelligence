# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_curve, auc

# %% [markdown]
# **Loading data**

# %%
x = torch.tensor(np.loadtxt('dataIn.txt', delimiter=' ', dtype=int)).float()
y = torch.tensor(np.loadtxt('dataOut.txt', delimiter=' ', dtype=int))#.float()

train_size = int(len(x) * 0.8)

train_dataset = TensorDataset(x[:train_size], y[:train_size])
test_dataset = TensorDataset(x[train_size:], y[train_size:])

batch_size = 100

train_dataloader = DataLoader(train_dataset, batch_size = batch_size)
test_dataloader = DataLoader(test_dataset, batch_size = batch_size)

for x, y in test_dataloader:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([100, 12])
# torch.Size([100])

# %% [markdown]
# **Generating data**

# %%
np.random.seed(42)

X = np.random.randint(0, 2, size=(100000, 12))

Y = np.random.randint(0, 2, size=(100000, 1))


np.savetxt('dataIn.txt', X, fmt='%d')

np.savetxt('dataOut.txt', Y, fmt='%d')

# %% [markdown]
# **Declaring model**

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")

class Perceptron(nn.Module):
    def __init__(self):
        super().__init__()
        self.lin_stack = nn.Sequential(
            nn.Linear(12, 10),
            nn.LogSigmoid(),
            nn.Linear(10, 7),
            nn.LogSigmoid(),
            nn.Linear(7, 2)
        )

    def forward(self, x):
        y = self.lin_stack(x)
        return y

model = Perceptron().to(device)
print(model)
# Out:
# Using cpu device
# Perceptron(
#   (lin_stack): Sequential(
#     (0): Linear(in_features=12, out_features=10, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=10, out_features=7, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=7, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# **Train model**

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    print(len(dataloader))
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        pred = model(X)
        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %% [markdown]
# **Testing**

# %%
def test(dataloader, model):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)

            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# **Training**

# %%
epochs = 5

print(len(train_dataloader))
print(len(test_dataloader))

for i in range(epochs):
    print(f"Epoch {i+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model)
# Out:
# 800
# 200
# Epoch 1
# -------------------------------
# 800
# loss: 0.771362  [  100/80000]
# loss: 0.740145  [10100/80000]
# loss: 0.735834  [20100/80000]
# loss: 0.709388  [30100/80000]
# loss: 0.708147  [40100/80000]
# loss: 0.697373  [50100/80000]
# loss: 0.698379  [60100/80000]
# loss: 0.701908  [70100/80000]
# Test Error: Accuracy: 49.2%, Avg loss: 0.694679
#
# Epoch 2
# -------------------------------
# 800
# loss: 0.696593  [  100/80000]
# loss: 0.694090  [10100/80000]
# loss: 0.692785  [20100/80000]
# loss: 0.691081  [30100/80000]
# loss: 0.692837  [40100/80000]
# loss: 0.694850  [50100/80000]
# loss: 0.692214  [60100/80000]
# loss: 0.692685  [70100/80000]
# Test Error: Accuracy: 49.6%, Avg loss: 0.693484
#
# Epoch 3
# -------------------------------
# 800
# loss: 0.694489  [  100/80000]
# loss: 0.692648  [10100/80000]
# loss: 0.690107  [20100/80000]
# loss: 0.690300  [30100/80000]
# loss: 0.691863  [40100/80000]
# loss: 0.694982  [50100/80000]
# loss: 0.691775  [60100/80000]
# loss: 0.691802  [70100/80000]
# Test Error: Accuracy: 49.9%, Avg loss: 0.693430
#
# Epoch 4
# -------------------------------
# 800
# loss: 0.694329  [  100/80000]
# loss: 0.692536  [10100/80000]
# loss: 0.689847  [20100/80000]
# loss: 0.690242  [30100/80000]
# loss: 0.691769  [40100/80000]
# loss: 0.694990  [50100/80000]
# loss: 0.691734  [60100/80000]
# loss: 0.691711  [70100/80000]
# Test Error: Accuracy: 49.8%, Avg loss: 0.693423
#
# Epoch 5
# -------------------------------
# 800
# loss: 0.694304  [  100/80000]
# loss: 0.692526  [10100/80000]
# loss: 0.689830  [20100/80000]
# loss: 0.690249  [30100/80000]
# loss: 0.691764  [40100/80000]
# loss: 0.694977  [50100/80000]
# loss: 0.691734  [60100/80000]
# loss: 0.691707  [70100/80000]
# Test Error: Accuracy: 49.8%, Avg loss: 0.693420

# %% [markdown]
# **Saving model**

# %%
model.save(model.state_dict(), 'model.pth')
