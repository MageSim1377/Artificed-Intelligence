# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, accuracy_score, classification_report
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('processed_titanic.csv')
df.head()
# Out:
#   PassengerId       Age  RoomService  FoodCourt  ShoppingMall    Spa  VRDeck  \
# 0     0013_01  0.341772        False      False         False  False   False
# 1     0018_01  0.240506        False      False         False  False   False
# 2     0019_01  0.392405        False      False         False  False   False
# 3     0021_01  0.481013        False      False         False  False   False
# 4     0023_01  0.253165        False      False         False  False   False
#
#    Transported       num  HomePlanet_Europa  ...  Destination_TRAPPIST-1e  \
# 0        False  0.001587              False  ...                     True
# 1        False  0.002116              False  ...                     True
# 2        False  0.000000               True  ...                    False
# 3        False  0.000529               True  ...                     True
# 4        False  0.002646              False  ...                     True
#
#    VIP_True  deck_B  deck_C  deck_D  deck_E  deck_F  deck_G  deck_T  side_S
# 0     False   False   False   False   False   False    True   False    True
# 1     False   False   False   False   False    True   False   False    True
# 2     False   False    True   False   False   False   False   False    True
# 3     False   False    True   False   False   False   False   False    True
# 4     False   False   False   False   False    True   False   False    True
#
# [5 rows x 23 columns]

# %%
df_not_normalized = pd.read_csv('not normalized processed titanic.csv')
df_not_normalized.head()
# Out:
#   PassengerId HomePlanet  CryoSleep  Destination   Age    VIP  RoomService  \
# 0     0013_01      Earth       True  TRAPPIST-1e  27.0  False        False
# 1     0018_01      Earth      False  TRAPPIST-1e  19.0  False        False
# 2     0019_01     Europa       True  55 Cancri e  31.0  False        False
# 3     0021_01     Europa      False  TRAPPIST-1e  38.0  False        False
# 4     0023_01      Earth      False  TRAPPIST-1e  20.0  False        False
#
#    FoodCourt  ShoppingMall    Spa  VRDeck  Transported deck  num side
# 0      False         False  False   False        False    G  3.0    S
# 1      False         False  False   False        False    F  4.0    S
# 2      False         False  False   False        False    C  0.0    S
# 3      False         False  False   False        False    C  1.0    S
# 4      False         False  False   False        False    F  5.0    S

# %%
# Regression

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop(['num'], axis=1), df_not_normalized['num'], test_size=0.4, random_state=42)

x_train.head()
# Out:
#      PassengerId       Age  RoomService  FoodCourt  ShoppingMall    Spa  \
# 3291     7211_01  0.392405        False      False         False  False
# 3945     8576_01  0.316456        False      False         False  False
# 801      1629_05  0.316456        False      False         False  False
# 2689     5911_06  0.126582        False      False         False  False
# 2131     4619_01  0.291139        False      False         False  False
#
#       VRDeck  Transported  HomePlanet_Europa  HomePlanet_Mars  ...  \
# 3291   False        False              False             True  ...
# 3945   False        False              False            False  ...
# 801    False        False               True            False  ...
# 2689   False        False              False            False  ...
# 2131   False        False              False            False  ...
#
#       Destination_TRAPPIST-1e  VIP_True  deck_B  deck_C  deck_D  deck_E  \
# 3291                     True     False   False   False   False    True
# 3945                    False     False   False    True   False   False
# 801                      True     False    True   False   False   False
# 2689                    False     False   False   False   False   False
# 2131                     True     False   False   False   False   False
#
#       deck_F  deck_G  deck_T  side_S
# 3291   False   False   False    True
# 3945   False   False   False    True
# 801    False   False   False    True
# 2689   False    True   False    True
# 2131    True   False   False    True
#
# [5 rows x 22 columns]

# %%
linear_model = LinearRegression()

n = 2
poly_features = PolynomialFeatures(n)
x_train = poly_features.fit_transform(x_train)
poly_features = PolynomialFeatures(n)
x_test = poly_features.fit_transform(x_test)

linear_model.fit(x_train, y_train)

y_pred = linear_model.predict(x_test)

rmse = root_mean_squared_error(y_test, y_pred)

print(rmse)
print(df_not_normalized['num'].describe())
# Out:
# 115.82137696186763
# count    4277.000000
# mean      606.246668
# std       509.545187
# min         0.000000
# 25%       179.000000
# 50%       442.000000
# 75%      1012.000000
# max      1890.000000
# Name: num, dtype: float64

# %%
# Classification

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop(['Transported'], axis=1), df['Transported'], test_size=0.4, random_state=42)

y_train.unique()
# Out:
# array([False])

# %%
logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)
y_pred = logreg_model.predict(x_test)

report = classification_report(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 logreg_model = LogisticRegression()
# ----> 3 logreg_model.fit(x_train, y_train)
#       4 y_pred = logreg_model.predict(x_test)
#       6 report = classification_report(y_test, y_pred)
#
# File D:\Уник работы\2 курс\Artificed Intelligence\.venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File D:\Уник работы\2 курс\Artificed Intelligence\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1243, in LogisticRegression.fit(self, X, y, sample_weight)
#    1240     max_squared_sum = None
#    1242 if n_classes < 2:
# -> 1243     raise ValueError(
#    1244         "This solver needs samples of at least 2 classes"
#    1245         " in the data, but the data contains only one"
#    1246         " class: %r" % self.classes_[0]
#    1247     )
#    1249 if self.warm_start:
#    1250     warm_start_coef = getattr(self, "coef_", None)
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: np.False_
